# %%
from gym_tradebi.dataloader.json import Dataloader
import numpy as np
import pandas as pd

# %%
source = Dataloader('../history/EUR_USD_H1_history.json')

# %%
d = source.getData()

# %%
list(d.columns.values)
# Out:
# ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
d.values[0]
# Out:
# array([1.16994e+00, 1.16996e+00, 1.16675e+00, 1.16738e+00, 4.81300e+03])

# %%
d['Open'].iloc[0]
# Out:
# 1.16994

# %%
high = np.array([])
y = np.array(["x"])
array_3 = np.append(high, y)
array_3
# Out:
# array(['x'], dtype='<U32')

# %%
for x in list(d.columns.values):
    high = np.append(high,np.array([d[x].max()]))

# %%
high
# Out:
# array([1.16994e+00, 1.16996e+00, 1.16834e+00, 1.16907e+00, 5.22800e+03])

# %%
d
# Out:
#                         Open     High      Low    Close  Volume
# Date_Time
# 2018-07-11 17:00:00  1.16994  1.16996  1.16675  1.16738  4813.0
# 2018-07-11 18:00:00  1.16736  1.16826  1.16656  1.16744  4523.0
# 2018-07-11 19:00:00  1.16744  1.16778  1.16685  1.16698  2424.0
# 2018-07-11 20:00:00  1.16700  1.16766  1.16700  1.16743   941.0
# 2018-07-11 21:00:00  1.16729  1.16809  1.16709  1.16740  3740.0
# 2018-07-11 22:00:00  1.16742  1.16772  1.16728  1.16764  1333.0
# 2018-07-11 23:00:00  1.16764  1.16781  1.16721  1.16751   753.0
# 2018-07-12 00:00:00  1.16746  1.16787  1.16702  1.16730   966.0
# 2018-07-12 01:00:00  1.16730  1.16800  1.16720  1.16747  1576.0
# 2018-07-12 02:00:00  1.16750  1.16800  1.16721  1.16728  1005.0
# 2018-07-12 03:00:00  1.16725  1.16775  1.16713  1.16760   841.0
# 2018-07-12 04:00:00  1.16760  1.16838  1.16756  1.16824   956.0
# 2018-07-12 05:00:00  1.16820  1.16866  1.16779  1.16788  1367.0
# ...

# %%
d['High'].max()
# Out:
# 1.16996
