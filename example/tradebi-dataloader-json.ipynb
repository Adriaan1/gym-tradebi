# %%
import gym
import gym_tradebi

# %%
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

# %%
from gym_tradebi.source.json import Dataloader

# %%
env = gym.make('tradebi-v0')

# %%
# Vectorized environments allow to easily multiprocess training
# we demonstrate its usefulness in the next examples
env = DummyVecEnv([lambda: env])  # The algorithms require a vectorized environment to run

# %%
model = PPO2(MlpPolicy, env, verbose=1)
# Train the agent
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")
# Out:
# --------------------------------------
# | approxkl           | 0.00010841927 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0164        |
# | fps                | 355           |
# | nupdates           | 1             |
# | policy_entropy     | 0.6930354     |
# | policy_loss        | -0.001241216  |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.91e-06      |
# | total_timesteps    | 128           |
# | value_loss         | 29.639193     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019864399 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00413      |
# | fps                | 1125          |
# | nupdates           | 2             |
# | policy_entropy     | 0.6922646     |
# | policy_loss        | -0.0055933213 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.361         |
# | total_timesteps    | 256           |
# | value_loss         | 58.030304     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033555014 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00222      |
# | fps                | 1200          |
# | nupdates           | 3             |
# | policy_entropy     | 0.6894052     |
# | policy_loss        | -0.0057379627 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.475         |
# | total_timesteps    | 384           |
# | value_loss         | 43.20753      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.519757e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00235        |
# | fps                | 1116           |
# | nupdates           | 4              |
# | policy_entropy     | 0.6886385      |
# | policy_loss        | -0.00096370804 |
# | serial_timesteps   | 512            |
# | time_elapsed       | 0.583          |
# | total_timesteps    | 512            |
# | value_loss         | 53.221912      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.4344648e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.015         |
# | fps                | 1222          |
# | nupdates           | 5             |
# | policy_entropy     | 0.6860471     |
# | policy_loss        | -0.0006807386 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 0.699         |
# | total_timesteps    | 640           |
# | value_loss         | 44.985783     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.8724264e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00663      |
# | fps                | 1173          |
# | nupdates           | 6             |
# | policy_entropy     | 0.68228716    |
# | policy_loss        | -0.0019073104 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 0.804         |
# | total_timesteps    | 768           |
# | value_loss         | 53.691566     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018744008 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000121      |
# | fps                | 1113          |
# | nupdates           | 7             |
# | policy_entropy     | 0.6732694     |
# | policy_loss        | -0.0018376273 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 0.914         |
# | total_timesteps    | 896           |
# | value_loss         | 69.67555      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017408948 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00467       |
# | fps                | 1145          |
# | nupdates           | 8             |
# | policy_entropy     | 0.67463994    |
# | policy_loss        | -0.0019290553 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 1.03          |
# | total_timesteps    | 1024          |
# | value_loss         | 40.37786      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000106765285 |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.000652      |
# | fps                | 1002           |
# | nupdates           | 9              |
# | policy_entropy     | 0.6704884      |
# | policy_loss        | -0.00083620986 |
# | serial_timesteps   | 1152           |
# | time_elapsed       | 1.14           |
# | total_timesteps    | 1152           |
# | value_loss         | 48.600838      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00032733037 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00902      |
# | fps                | 1184          |
# | nupdates           | 10            |
# | policy_entropy     | 0.65595424    |
# | policy_loss        | -0.0036451006 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 1.27          |
# | total_timesteps    | 1280          |
# | value_loss         | 36.253593     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005188313  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00809      |
# | fps                | 797           |
# | nupdates           | 11            |
# | policy_entropy     | 0.6472588     |
# | policy_loss        | -0.0040372373 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 1.38          |
# | total_timesteps    | 1408          |
# | value_loss         | 44.60837      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009107146  |
# | clipfrac           | 0.001953125   |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0279       |
# | fps                | 664           |
# | nupdates           | 12            |
# | policy_entropy     | 0.63394785    |
# | policy_loss        | -0.0074355835 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 1.54          |
# | total_timesteps    | 1536          |
# | value_loss         | 42.670006     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019872587 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00371      |
# | fps                | 731           |
# | nupdates           | 13            |
# | policy_entropy     | 0.64937145    |
# | policy_loss        | -8.618715e-05 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 1.74          |
# | total_timesteps    | 1664          |
# | value_loss         | 52.5965       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.90908e-05   |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0211        |
# | fps                | 822           |
# | nupdates           | 14            |
# | policy_entropy     | 0.6427927     |
# | policy_loss        | -0.0013370233 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 1.91          |
# | total_timesteps    | 1792          |
# | value_loss         | 49.798645     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011606663 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00221      |
# | fps                | 1071          |
# | nupdates           | 15            |
# | policy_entropy     | 0.6305408     |
# | policy_loss        | -0.0028550234 |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 2.07          |
# | total_timesteps    | 1920          |
# | value_loss         | 61.9179       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002729721  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00022      |
# | fps                | 1254          |
# | nupdates           | 16            |
# | policy_entropy     | 0.62198716    |
# | policy_loss        | -0.0017738297 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 2.19          |
# | total_timesteps    | 2048          |
# | value_loss         | 61.89952      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004856586  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.015         |
# | fps                | 991           |
# | nupdates           | 17            |
# | policy_entropy     | 0.62015253    |
# | policy_loss        | -0.0018166078 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 2.29          |
# | total_timesteps    | 2176          |
# | value_loss         | 50.18446      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1377247e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00391       |
# | fps                | 1088          |
# | nupdates           | 18            |
# | policy_entropy     | 0.6411722     |
# | policy_loss        | 0.0007517376  |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 2.42          |
# | total_timesteps    | 2304          |
# | value_loss         | 60.068245     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010496941 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.0155       |
# | fps                | 1085         |
# | nupdates           | 19           |
# | policy_entropy     | 0.62435734   |
# | policy_loss        | 0.003151274  |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 2.54         |
# | total_timesteps    | 2432         |
# | value_loss         | 78.03623     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 6.320259e-06  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00309      |
# | fps                | 799           |
# | nupdates           | 20            |
# | policy_entropy     | 0.6153172     |
# | policy_loss        | 0.00016738946 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 2.66          |
# | total_timesteps    | 2560          |
# | value_loss         | 58.97093      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0308373e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0328        |
# | fps                | 988           |
# | nupdates           | 21            |
# | policy_entropy     | 0.6077127     |
# | policy_loss        | 3.475719e-05  |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 2.82          |
# | total_timesteps    | 2688          |
# | value_loss         | 77.53257      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 5.86212e-05  |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | -0.0049      |
# | fps                | 1109         |
# | nupdates           | 22           |
# | policy_entropy     | 0.6168518    |
# | policy_loss        | 0.0006657315 |
# | serial_timesteps   | 2816         |
# | time_elapsed       | 2.95         |
# | total_timesteps    | 2816         |
# | value_loss         | 77.21302     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0002864914  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.015         |
# | fps                | 1222          |
# | nupdates           | 23            |
# | policy_entropy     | 0.61705226    |
# | policy_loss        | -0.0028621806 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 3.07          |
# | total_timesteps    | 2944          |
# | value_loss         | 71.27917      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.4830762e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0159         |
# | fps                | 1181           |
# | nupdates           | 24             |
# | policy_entropy     | 0.60366374     |
# | policy_loss        | -0.00037857395 |
# | serial_timesteps   | 3072           |
# | time_elapsed       | 3.17           |
# | total_timesteps    | 3072           |
# | value_loss         | 55.8527        |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 4.504643e-05 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.0132       |
# | fps                | 1252         |
# | nupdates           | 25           |
# | policy_entropy     | 0.60040295   |
# | policy_loss        | -0.001144965 |
# | serial_timesteps   | 3200         |
# | time_elapsed       | 3.28         |
# | total_timesteps    | 3200         |
# | value_loss         | 52.06023     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00015116335 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.013         |
# | fps                | 1265          |
# | nupdates           | 26            |
# | policy_entropy     | 0.60608375    |
# | policy_loss        | -0.0011906376 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 3.38          |
# | total_timesteps    | 3328          |
# | value_loss         | 65.27599      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.578943e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0124        |
# | fps                | 1279          |
# | nupdates           | 27            |
# | policy_entropy     | 0.60456795    |
# | policy_loss        | -0.0009707704 |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 3.49          |
# | total_timesteps    | 3456          |
# | value_loss         | 35.122303     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.97944e-05   |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0198        |
# | fps                | 1168          |
# | nupdates           | 28            |
# | policy_entropy     | 0.5935577     |
# | policy_loss        | -0.0016184913 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 3.59          |
# | total_timesteps    | 3584          |
# | value_loss         | 53.351196     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.623332e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0549        |
# | fps                | 1291          |
# | nupdates           | 29            |
# | policy_entropy     | 0.6338789     |
# | policy_loss        | -0.0011666853 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 3.7           |
# | total_timesteps    | 3712          |
# | value_loss         | 73.58055      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.819408e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0363        |
# | fps                | 1158          |
# | nupdates           | 30            |
# | policy_entropy     | 0.59515333    |
# | policy_loss        | -0.0016845965 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 3.8           |
# | total_timesteps    | 3840          |
# | value_loss         | 54.414318     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.2057293e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00872       |
# | fps                | 1294          |
# | nupdates           | 31            |
# | policy_entropy     | 0.6091606     |
# | policy_loss        | -0.0009290186 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 3.91          |
# | total_timesteps    | 3968          |
# | value_loss         | 75.95686      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006465693  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0357        |
# | fps                | 1299          |
# | nupdates           | 32            |
# | policy_entropy     | 0.6036443     |
# | policy_loss        | -0.0037689349 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 4.01          |
# | total_timesteps    | 4096          |
# | value_loss         | 49.803707     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.173224e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00344        |
# | fps                | 1290           |
# | nupdates           | 33             |
# | policy_entropy     | 0.58269787     |
# | policy_loss        | -0.00053518126 |
# | serial_timesteps   | 4224           |
# | time_elapsed       | 4.11           |
# | total_timesteps    | 4224           |
# | value_loss         | 53.077053      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.1300004e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00131      |
# | fps                | 1316          |
# | nupdates           | 34            |
# | policy_entropy     | 0.5778997     |
# | policy_loss        | -0.0016438806 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 4.21          |
# | total_timesteps    | 4352          |
# | value_loss         | 35.258476     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.2111948e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00214        |
# | fps                | 1192           |
# | nupdates           | 35             |
# | policy_entropy     | 0.59474695     |
# | policy_loss        | -0.00018385216 |
# | serial_timesteps   | 4480           |
# | time_elapsed       | 4.31           |
# | total_timesteps    | 4480           |
# | value_loss         | 63.992043      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.3538481e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0335        |
# | fps                | 1294          |
# | nupdates           | 36            |
# | policy_entropy     | 0.6193249     |
# | policy_loss        | 0.00021320337 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 4.42          |
# | total_timesteps    | 4608          |
# | value_loss         | 63.091896     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018311254 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.018        |
# | fps                | 1304          |
# | nupdates           | 37            |
# | policy_entropy     | 0.61540693    |
# | policy_loss        | -0.003379359  |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 4.51          |
# | total_timesteps    | 4736          |
# | value_loss         | 63.9169       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.1860836e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0113        |
# | fps                | 1192          |
# | nupdates           | 38            |
# | policy_entropy     | 0.56521505    |
# | policy_loss        | -0.0004274235 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 4.61          |
# | total_timesteps    | 4864          |
# | value_loss         | 32.055546     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4538589e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.137        |
# | fps                | 1310          |
# | nupdates           | 39            |
# | policy_entropy     | 0.6058484     |
# | policy_loss        | 0.00031392556 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 4.72          |
# | total_timesteps    | 4992          |
# | value_loss         | 89.34846      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.403552e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00982       |
# | fps                | 1283          |
# | nupdates           | 40            |
# | policy_entropy     | 0.5731235     |
# | policy_loss        | -0.0015515859 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 4.82          |
# | total_timesteps    | 5120          |
# | value_loss         | 49.789154     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007388783  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0131        |
# | fps                | 1202          |
# | nupdates           | 41            |
# | policy_entropy     | 0.5632953     |
# | policy_loss        | -0.0045493734 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 4.92          |
# | total_timesteps    | 5248          |
# | value_loss         | 44.618866     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00037588028 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0245        |
# | fps                | 1271          |
# | nupdates           | 42            |
# | policy_entropy     | 0.57401794    |
# | policy_loss        | -0.0013713305 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 5.03          |
# | total_timesteps    | 5376          |
# | value_loss         | 43.00453      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.180951e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0382        |
# | fps                | 1291          |
# | nupdates           | 43            |
# | policy_entropy     | 0.590538      |
# | policy_loss        | -0.0016942343 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 5.13          |
# | total_timesteps    | 5504          |
# | value_loss         | 59.550343     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00030223184 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0131        |
# | fps                | 1283          |
# | nupdates           | 44            |
# | policy_entropy     | 0.58033       |
# | policy_loss        | -0.0011086793 |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 5.23          |
# | total_timesteps    | 5632          |
# | value_loss         | 64.338326     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00059317617 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0593        |
# | fps                | 1285          |
# | nupdates           | 45            |
# | policy_entropy     | 0.56825596    |
# | policy_loss        | -0.0045209057 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 5.33          |
# | total_timesteps    | 5760          |
# | value_loss         | 44.421543     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000108030334 |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0679         |
# | fps                | 1219           |
# | nupdates           | 46             |
# | policy_entropy     | 0.6040256      |
# | policy_loss        | 0.0019790898   |
# | serial_timesteps   | 5888           |
# | time_elapsed       | 5.43           |
# | total_timesteps    | 5888           |
# | value_loss         | 56.91578       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.5337564e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.25         |
# | fps                | 1249          |
# | nupdates           | 47            |
# | policy_entropy     | 0.6169097     |
# | policy_loss        | -0.0013041529 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 5.54          |
# | total_timesteps    | 6016          |
# | value_loss         | 84.64662      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020224713 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00951      |
# | fps                | 1277          |
# | nupdates           | 48            |
# | policy_entropy     | 0.5808848     |
# | policy_loss        | -0.0034345484 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 5.64          |
# | total_timesteps    | 6144          |
# | value_loss         | 62.104214     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005800265  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00537      |
# | fps                | 1307          |
# | nupdates           | 49            |
# | policy_entropy     | 0.53242296    |
# | policy_loss        | -0.0015461756 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 5.74          |
# | total_timesteps    | 6272          |
# | value_loss         | 46.158836     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7080055e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0823        |
# | fps                | 1306          |
# | nupdates           | 50            |
# | policy_entropy     | 0.57508755    |
# | policy_loss        | 0.0010447179  |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 5.84          |
# | total_timesteps    | 6400          |
# | value_loss         | 57.27679      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.764494e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.103         |
# | fps                | 1304          |
# | nupdates           | 51            |
# | policy_entropy     | 0.5827569     |
# | policy_loss        | 0.00019825716 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 5.94          |
# | total_timesteps    | 6528          |
# | value_loss         | 76.61754      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0006670983 |
# | clipfrac           | 0.009765625  |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.00299      |
# | fps                | 1192         |
# | nupdates           | 52           |
# | policy_entropy     | 0.5645002    |
# | policy_loss        | 0.00497162   |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 6.04         |
# | total_timesteps    | 6656         |
# | value_loss         | 76.860275    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00014330768 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0792       |
# | fps                | 1299          |
# | nupdates           | 53            |
# | policy_entropy     | 0.5867641     |
# | policy_loss        | 0.0007540891  |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 6.15          |
# | total_timesteps    | 6784          |
# | value_loss         | 77.12885      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.3941324e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.015         |
# | fps                | 1290           |
# | nupdates           | 54             |
# | policy_entropy     | 0.55759966     |
# | policy_loss        | -0.00019041717 |
# | serial_timesteps   | 6912           |
# | time_elapsed       | 6.25           |
# | total_timesteps    | 6912           |
# | value_loss         | 75.40568       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00024981657 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.242         |
# | fps                | 1283          |
# | nupdates           | 55            |
# | policy_entropy     | 0.58245337    |
# | policy_loss        | -0.000325848  |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 6.35          |
# | total_timesteps    | 7040          |
# | value_loss         | 76.03119      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.001356e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0453         |
# | fps                | 1279           |
# | nupdates           | 56             |
# | policy_entropy     | 0.6088822      |
# | policy_loss        | -0.00035165588 |
# | serial_timesteps   | 7168           |
# | time_elapsed       | 6.45           |
# | total_timesteps    | 7168           |
# | value_loss         | 75.251         |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 4.930178e-05 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.0288       |
# | fps                | 1140         |
# | nupdates           | 57           |
# | policy_entropy     | 0.60179585   |
# | policy_loss        | -0.000237745 |
# | serial_timesteps   | 7296         |
# | time_elapsed       | 6.55         |
# | total_timesteps    | 7296         |
# | value_loss         | 57.899475    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0003521099  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00338      |
# | fps                | 1260          |
# | nupdates           | 58            |
# | policy_entropy     | 0.557385      |
# | policy_loss        | -0.0029635443 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 6.66          |
# | total_timesteps    | 7424          |
# | value_loss         | 36.971107     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013654235 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0326        |
# | fps                | 1312          |
# | nupdates           | 59            |
# | policy_entropy     | 0.5897807     |
# | policy_loss        | -5.164207e-05 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 6.76          |
# | total_timesteps    | 7552          |
# | value_loss         | 72.81043      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004389479   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00907        |
# | fps                | 1293           |
# | nupdates           | 60             |
# | policy_entropy     | 0.60202545     |
# | policy_loss        | -0.00029807712 |
# | serial_timesteps   | 7680           |
# | time_elapsed       | 6.86           |
# | total_timesteps    | 7680           |
# | value_loss         | 60.756775      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.4473396e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0343       |
# | fps                | 1193          |
# | nupdates           | 61            |
# | policy_entropy     | 0.5996368     |
# | policy_loss        | -0.0012364329 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 6.96          |
# | total_timesteps    | 7808          |
# | value_loss         | 72.12381      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.986223e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00403       |
# | fps                | 1290          |
# | nupdates           | 62            |
# | policy_entropy     | 0.5998478     |
# | policy_loss        | 0.00068036304 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 7.07          |
# | total_timesteps    | 7936          |
# | value_loss         | 52.345158     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.1180443e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0601         |
# | fps                | 1192           |
# | nupdates           | 63             |
# | policy_entropy     | 0.61549366     |
# | policy_loss        | -0.00039679883 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 7.17           |
# | total_timesteps    | 8064           |
# | value_loss         | 70.412766      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.2460768e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0139        |
# | fps                | 1265           |
# | nupdates           | 64             |
# | policy_entropy     | 0.6030021      |
# | policy_loss        | -0.00040787237 |
# | serial_timesteps   | 8192           |
# | time_elapsed       | 7.28           |
# | total_timesteps    | 8192           |
# | value_loss         | 51.813854      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012611052 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000797      |
# | fps                | 1280          |
# | nupdates           | 65            |
# | policy_entropy     | 0.60148793    |
# | policy_loss        | 0.0012589912  |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 7.38          |
# | total_timesteps    | 8320          |
# | value_loss         | 69.579025     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7344723e-06 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0598       |
# | fps                | 1288          |
# | nupdates           | 66            |
# | policy_entropy     | 0.5804119     |
# | policy_loss        | -0.0003755972 |
# | serial_timesteps   | 8448          |
# | time_elapsed       | 7.48          |
# | total_timesteps    | 8448          |
# | value_loss         | 70.07008      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.3380319e-06  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0221         |
# | fps                | 1185           |
# | nupdates           | 67             |
# | policy_entropy     | 0.5875693      |
# | policy_loss        | -5.3322874e-06 |
# | serial_timesteps   | 8576           |
# | time_elapsed       | 7.58           |
# | total_timesteps    | 8576           |
# | value_loss         | 67.97063       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.7852223e-06  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0186        |
# | fps                | 1240           |
# | nupdates           | 68             |
# | policy_entropy     | 0.59843236     |
# | policy_loss        | -0.00025784154 |
# | serial_timesteps   | 8704           |
# | time_elapsed       | 7.69           |
# | total_timesteps    | 8704           |
# | value_loss         | 67.90844       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.1777986e-06 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0926        |
# | fps                | 1254          |
# | nupdates           | 69            |
# | policy_entropy     | 0.59167886    |
# | policy_loss        | 0.00020553614 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 7.8           |
# | total_timesteps    | 8832          |
# | value_loss         | 67.10544      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.6860473e-07  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0118         |
# | fps                | 1287           |
# | nupdates           | 70             |
# | policy_entropy     | 0.6107624      |
# | policy_loss        | -4.4037122e-05 |
# | serial_timesteps   | 8960           |
# | time_elapsed       | 7.9            |
# | total_timesteps    | 8960           |
# | value_loss         | 68.44379       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00010194321 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0313        |
# | fps                | 1233          |
# | nupdates           | 71            |
# | policy_entropy     | 0.60580015    |
# | policy_loss        | 0.00035674148 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 8             |
# | total_timesteps    | 9088          |
# | value_loss         | 65.57445      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.6730148e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0212         |
# | fps                | 1284           |
# | nupdates           | 72             |
# | policy_entropy     | 0.5968361      |
# | policy_loss        | -0.00065191987 |
# | serial_timesteps   | 9216           |
# | time_elapsed       | 8.1            |
# | total_timesteps    | 9216           |
# | value_loss         | 64.816315      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0043377983  |
# | clipfrac           | 0.048828125   |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000975      |
# | fps                | 1266          |
# | nupdates           | 73            |
# | policy_entropy     | 0.6133021     |
# | policy_loss        | -0.0051355055 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 8.2           |
# | total_timesteps    | 9344          |
# | value_loss         | 51.829716     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023070995 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0205        |
# | fps                | 1220          |
# | nupdates           | 74            |
# | policy_entropy     | 0.57630676    |
# | policy_loss        | 0.0034423834  |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 8.31          |
# | total_timesteps    | 9472          |
# | value_loss         | 59.46716      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4021654e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00932       |
# | fps                | 1304          |
# | nupdates           | 75            |
# | policy_entropy     | 0.576679      |
# | policy_loss        | -0.0005364418 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 8.41          |
# | total_timesteps    | 9600          |
# | value_loss         | 52.994118     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4746595e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.018         |
# | fps                | 1306          |
# | nupdates           | 76            |
# | policy_entropy     | 0.58601224    |
# | policy_loss        | 0.00023027882 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 8.51          |
# | total_timesteps    | 9728          |
# | value_loss         | 63.01777      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.0087263e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0111        |
# | fps                | 1220          |
# | nupdates           | 77            |
# | policy_entropy     | 0.5801881     |
# | policy_loss        | -0.0013917929 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 8.61          |
# | total_timesteps    | 9856          |
# | value_loss         | 49.83766      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033545916 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00749       |
# | fps                | 1289          |
# | nupdates           | 78            |
# | policy_entropy     | 0.5409655     |
# | policy_loss        | -0.0022072243 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 8.72          |
# | total_timesteps    | 9984          |
# | value_loss         | 58.007465     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0018564432 |
# | clipfrac           | 0.01171875   |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.00907      |
# | fps                | 1283         |
# | nupdates           | 79           |
# | policy_entropy     | 0.5585106    |
# | policy_loss        | -0.011452859 |
# | serial_timesteps   | 10112        |
# | time_elapsed       | 8.82         |
# | total_timesteps    | 10112        |
# | value_loss         | 50.648018    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021826093 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0565        |
# | fps                | 1043          |
# | nupdates           | 80            |
# | policy_entropy     | 0.5838714     |
# | policy_loss        | -0.0004864228 |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 8.92          |
# | total_timesteps    | 10240         |
# | value_loss         | 61.251904     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.0565645e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0214        |
# | fps                | 1049          |
# | nupdates           | 81            |
# | policy_entropy     | 0.5784065     |
# | policy_loss        | -0.0009922073 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 9.04          |
# | total_timesteps    | 10368         |
# | value_loss         | 66.853485     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026844873 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0105        |
# | fps                | 1265          |
# | nupdates           | 82            |
# | policy_entropy     | 0.55625165    |
# | policy_loss        | 0.0011902701  |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 9.16          |
# ...
# | time_elapsed       | 20.8          |
# | total_timesteps    | 21504         |
# | value_loss         | 74.34578      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005030022 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | -0.00147     |
# | fps                | 758          |
# | nupdates           | 169          |
# | policy_entropy     | 0.5564632    |
# | policy_loss        | 0.0007181313 |
# | serial_timesteps   | 21632        |
# | time_elapsed       | 21           |
# | total_timesteps    | 21632        |
# | value_loss         | 31.429718    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.8023955e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0235        |
# | fps                | 674           |
# | nupdates           | 170           |
# | policy_entropy     | 0.54914945    |
# | policy_loss        | 0.0006893636  |
# | serial_timesteps   | 21760         |
# | time_elapsed       | 21.1          |
# | total_timesteps    | 21760         |
# | value_loss         | 30.95675      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000108066226 |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00203        |
# | fps                | 790            |
# | nupdates           | 171            |
# | policy_entropy     | 0.5799413      |
# | policy_loss        | -0.0011224493  |
# | serial_timesteps   | 21888          |
# | time_elapsed       | 21.3           |
# | total_timesteps    | 21888          |
# | value_loss         | 74.755035      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00011643297 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00738       |
# | fps                | 844           |
# | nupdates           | 172           |
# | policy_entropy     | 0.55286777    |
# | policy_loss        | -0.0030937165 |
# | serial_timesteps   | 22016         |
# | time_elapsed       | 21.5          |
# | total_timesteps    | 22016         |
# | value_loss         | 30.643614     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.284597e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.00619       |
# | fps                | 788            |
# | nupdates           | 173            |
# | policy_entropy     | 0.55808246     |
# | policy_loss        | -0.00037864223 |
# | serial_timesteps   | 22144          |
# | time_elapsed       | 21.6           |
# | total_timesteps    | 22144          |
# | value_loss         | 30.222973      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015911981  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.014          |
# | fps                | 816            |
# | nupdates           | 174            |
# | policy_entropy     | 0.56779796     |
# | policy_loss        | -0.00057313545 |
# | serial_timesteps   | 22272          |
# | time_elapsed       | 21.8           |
# | total_timesteps    | 22272          |
# | value_loss         | 29.929466      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.386497e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0144        |
# | fps                | 821            |
# | nupdates           | 175            |
# | policy_entropy     | 0.5894556      |
# | policy_loss        | -0.00026120874 |
# | serial_timesteps   | 22400          |
# | time_elapsed       | 22             |
# | total_timesteps    | 22400          |
# | value_loss         | 29.6437        |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.8648515e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -4.2e-05       |
# | fps                | 729            |
# | nupdates           | 176            |
# | policy_entropy     | 0.53818077     |
# | policy_loss        | -0.00092089456 |
# | serial_timesteps   | 22528          |
# | time_elapsed       | 22.1           |
# | total_timesteps    | 22528          |
# | value_loss         | 80.37945       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0021715546 |
# | clipfrac           | 0.025390625  |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.000926     |
# | fps                | 839          |
# | nupdates           | 177          |
# | policy_entropy     | 0.5626825    |
# | policy_loss        | -0.008978009 |
# | serial_timesteps   | 22656        |
# | time_elapsed       | 22.3         |
# | total_timesteps    | 22656        |
# | value_loss         | 76.329414    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00021185252  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0106         |
# | fps                | 805            |
# | nupdates           | 178            |
# | policy_entropy     | 0.56985736     |
# | policy_loss        | -0.00025505968 |
# | serial_timesteps   | 22784          |
# | time_elapsed       | 22.4           |
# | total_timesteps    | 22784          |
# | value_loss         | 29.399532      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.571831e-06   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00115        |
# | fps                | 837            |
# | nupdates           | 179            |
# | policy_entropy     | 0.56536955     |
# | policy_loss        | -0.00077412254 |
# | serial_timesteps   | 22912          |
# | time_elapsed       | 22.6           |
# | total_timesteps    | 22912          |
# | value_loss         | 51.78879       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.001799318  |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.00451      |
# | fps                | 882          |
# | nupdates           | 180          |
# | policy_entropy     | 0.5778243    |
# | policy_loss        | -0.005096054 |
# | serial_timesteps   | 23040        |
# | time_elapsed       | 22.8         |
# | total_timesteps    | 23040        |
# | value_loss         | 28.678558    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 4.047547e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.00519       |
# | fps                | 1001           |
# | nupdates           | 181            |
# | policy_entropy     | 0.5526918      |
# | policy_loss        | -1.0055373e-05 |
# | serial_timesteps   | 23168          |
# | time_elapsed       | 22.9           |
# | total_timesteps    | 23168          |
# | value_loss         | 28.309021      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0046579773  |
# | clipfrac           | 0.078125      |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00059       |
# | fps                | 949           |
# | nupdates           | 182           |
# | policy_entropy     | 0.5374338     |
# | policy_loss        | -0.0121140685 |
# | serial_timesteps   | 23296         |
# | time_elapsed       | 23            |
# | total_timesteps    | 23296         |
# | value_loss         | 78.04885      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0881856e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00429      |
# | fps                | 1215          |
# | nupdates           | 183           |
# | policy_entropy     | 0.5527898     |
# | policy_loss        | 0.00029807212 |
# | serial_timesteps   | 23424         |
# | time_elapsed       | 23.2          |
# | total_timesteps    | 23424         |
# | value_loss         | 28.335552     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.0539243e-06  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.000458      |
# | fps                | 949            |
# | nupdates           | 184            |
# | policy_entropy     | 0.56507653     |
# | policy_loss        | -0.00017618423 |
# | serial_timesteps   | 23552          |
# | time_elapsed       | 23.3           |
# | total_timesteps    | 23552          |
# | value_loss         | 27.75749       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0008795333 |
# | clipfrac           | 0.00390625   |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.000469     |
# | fps                | 784          |
# | nupdates           | 185          |
# | policy_entropy     | 0.5876075    |
# | policy_loss        | -0.006339326 |
# | serial_timesteps   | 23680        |
# | time_elapsed       | 23.4         |
# | total_timesteps    | 23680        |
# | value_loss         | 80.52156     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004685684   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00415        |
# | fps                | 770            |
# | nupdates           | 186            |
# | policy_entropy     | 0.54566395     |
# | policy_loss        | -0.00079153467 |
# | serial_timesteps   | 23808          |
# | time_elapsed       | 23.6           |
# | total_timesteps    | 23808          |
# | value_loss         | 27.700783      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0013457703 |
# | clipfrac           | 0.01171875   |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.00172      |
# | fps                | 832          |
# | nupdates           | 187          |
# | policy_entropy     | 0.5339338    |
# | policy_loss        | -0.010894261 |
# | serial_timesteps   | 23936        |
# | time_elapsed       | 23.7         |
# | total_timesteps    | 23936        |
# | value_loss         | 79.52188     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 7.1864844e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00125      |
# | fps                | 812           |
# | nupdates           | 188           |
# | policy_entropy     | 0.5815744     |
# | policy_loss        | 0.00066781207 |
# | serial_timesteps   | 24064         |
# | time_elapsed       | 23.9          |
# | total_timesteps    | 24064         |
# | value_loss         | 27.444935     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001245306   |
# | clipfrac           | 0.009765625   |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000481      |
# | fps                | 827           |
# | nupdates           | 189           |
# | policy_entropy     | 0.55977523    |
# | policy_loss        | -0.0042244764 |
# | serial_timesteps   | 24192         |
# | time_elapsed       | 24.1          |
# | total_timesteps    | 24192         |
# | value_loss         | 80.827866     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005172042  |
# | clipfrac           | 0.07421875   |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.000543     |
# | fps                | 779          |
# | nupdates           | 190          |
# | policy_entropy     | 0.5767216    |
# | policy_loss        | -0.008451689 |
# | serial_timesteps   | 24320        |
# | time_elapsed       | 24.2         |
# | total_timesteps    | 24320        |
# | value_loss         | 85.724464    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.3159943e-06 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00132      |
# | fps                | 845           |
# | nupdates           | 191           |
# | policy_entropy     | 0.5578728     |
# | policy_loss        | 0.00021789625 |
# | serial_timesteps   | 24448         |
# | time_elapsed       | 24.4          |
# | total_timesteps    | 24448         |
# | value_loss         | 27.21709      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044657046 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -6.66e-05     |
# | fps                | 1032          |
# | nupdates           | 192           |
# | policy_entropy     | 0.5520304     |
# | policy_loss        | -0.003250528  |
# | serial_timesteps   | 24576         |
# | time_elapsed       | 24.5          |
# | total_timesteps    | 24576         |
# | value_loss         | 82.3133       |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010012919 |
# | clipfrac           | 0.00390625   |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | -6.21e-05    |
# | fps                | 1204         |
# | nupdates           | 193          |
# | policy_entropy     | 0.5311624    |
# | policy_loss        | -0.010426232 |
# | serial_timesteps   | 24704        |
# | time_elapsed       | 24.7         |
# | total_timesteps    | 24704        |
# | value_loss         | 88.26987     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012866796  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000533      |
# | fps                | 1174          |
# | nupdates           | 194           |
# | policy_entropy     | 0.5485883     |
# | policy_loss        | -0.0008609756 |
# | serial_timesteps   | 24832         |
# | time_elapsed       | 24.8          |
# | total_timesteps    | 24832         |
# | value_loss         | 81.20302      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.7836574e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.00692       |
# | fps                | 1214          |
# | nupdates           | 195           |
# | policy_entropy     | 0.5509685     |
# | policy_loss        | 0.0001124969  |
# | serial_timesteps   | 24960         |
# | time_elapsed       | 24.9          |
# | total_timesteps    | 24960         |
# | value_loss         | 26.76864      |
# --------------------------------------

# %%
del model # remove to demonstrate saving and loading

# %%
model = PPO2.load("ppo2_cartpole")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.

# %%
# Enjoy trained agent
obs = env.reset()

# %%
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9232eba46886> in <module>()
#       2     action, _states = model.predict(obs)
#       3     obs, rewards, dones, info = env.step(action)
# ----> 4     env.render()
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in render(self, mode)
#      62
#      63     def render(self, mode='human'):
# ---> 64         return [e.render(mode=mode) for e in self.envs]
#      65
#      66     def _save_obs(self, env_idx, obs):
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/stable_baselines/common/vec_env/dummy_vec_env.py in <listcomp>(.0)
#      62
#      63     def render(self, mode='human'):
# ---> 64         return [e.render(mode=mode) for e in self.envs]
#      65
#      66     def _save_obs(self, env_idx, obs):
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/gym/core.py in render(self, mode)
#     282
#     283     def render(self, mode='human'):
# --> 284         return self.env.render(mode)
#     285
#     286     def close(self):
#
# ~/Documents/code/tf/gym-tradebi/gym_tradebi/envs/tradebi_env.py in render(self, mode)
#     182         x = self.state
#     183         cartx = x[0]*scale+screen_width/2.0 # MIDDLE OF CART
# --> 184         self.carttrans.set_translation(cartx, carty)
#     185         self.poletrans.set_rotation(-x[2])
#     186
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in set_translation(self, newx, newy)
#     185         glPopMatrix()
#     186     def set_translation(self, newx, newy):
# --> 187         self.translation = (float(newx), float(newy))
#     188     def set_rotation(self, new):
#     189         self.rotation = float(new)
#
# KeyboardInterrupt:
