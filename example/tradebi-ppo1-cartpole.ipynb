# %%
import gym
import gym_tradebi

from stable_baselines.common.policies import MlpPolicy, MlpLstmPolicy, MlpLnLstmPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO1

# %%
env = gym.make('tradebi-v0')

# %%
env = DummyVecEnv([lambda: env])

# %%
model = PPO1(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo1_cartpole")
# Out:
# ********** Iteration 0 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00369 |      -0.00693 |      69.81242 |       0.00018 |       0.69298
#      -0.01355 |      -0.00692 |      68.54941 |       0.00170 |       0.69152
#      -0.02140 |      -0.00687 |      67.29089 |       0.00594 |       0.68740
#      -0.02439 |      -0.00682 |      66.02412 |       0.01185 |       0.68170
# Evaluating losses...
#      -0.02323 |      -0.00679 |      65.11394 |       0.01473 |       0.67894
# ----------------------------------
# | EpLenMean       | 19.4         |
# | EpRewMean       | 19.4         |
# | EpThisIter      | 12           |
# | EpisodesSoFar   | 12           |
# | TimeElapsed     | 0.554        |
# | TimestepsSoFar  | 256          |
# | ev_tdlam_before | -0.0176      |
# | loss_ent        | 0.6789434    |
# | loss_kl         | 0.014731428  |
# | loss_pol_entpen | -0.006789434 |
# | loss_pol_surr   | -0.023234272 |
# | loss_vf_loss    | 65.11394     |
# ----------------------------------
# ********** Iteration 1 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00357 |      -0.00682 |     111.02541 |       0.00010 |       0.68233
#      -0.01653 |      -0.00676 |     107.87910 |       0.00143 |       0.67570
#      -0.02670 |      -0.00665 |     104.10371 |       0.00556 |       0.66505
#      -0.02816 |      -0.00652 |     100.02067 |       0.01250 |       0.65237
# Evaluating losses...
#      -0.02862 |      -0.00647 |      97.17419 |       0.01597 |       0.64683
# ----------------------------------
# | EpLenMean       | 22.8         |
# | EpRewMean       | 22.8         |
# | EpThisIter      | 10           |
# | EpisodesSoFar   | 22           |
# | TimeElapsed     | 0.83         |
# | TimestepsSoFar  | 535          |
# | ev_tdlam_before | 0.049        |
# | loss_ent        | 0.6468257    |
# | loss_kl         | 0.015970843  |
# | loss_pol_entpen | -0.006468257 |
# | loss_pol_surr   | -0.028622221 |
# | loss_vf_loss    | 97.17419     |
# ----------------------------------
# ********** Iteration 2 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00051 |      -0.00666 |     125.61361 |      5.80e-05 |       0.66637
#      -0.00246 |      -0.00661 |     121.46075 |       0.00056 |       0.66116
#      -0.00434 |      -0.00656 |     116.33665 |       0.00156 |       0.65571
#      -0.00545 |      -0.00650 |     110.46828 |       0.00308 |       0.65017
# Evaluating losses...
#      -0.00511 |      -0.00647 |     106.57952 |       0.00412 |       0.64698
# -----------------------------------
# | EpLenMean       | 26.6          |
# | EpRewMean       | 26.6          |
# | EpThisIter      | 6             |
# | EpisodesSoFar   | 28            |
# | TimeElapsed     | 1.12          |
# | TimestepsSoFar  | 802           |
# | ev_tdlam_before | 0.0166        |
# | loss_ent        | 0.64697945    |
# | loss_kl         | 0.0041201916  |
# | loss_pol_entpen | -0.0064697945 |
# | loss_pol_surr   | -0.0051097553 |
# | loss_vf_loss    | 106.57952     |
# -----------------------------------
# ********** Iteration 3 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00010 |      -0.00653 |     158.97310 |      2.27e-05 |       0.65253
#      -0.00087 |      -0.00649 |     149.01627 |       0.00018 |       0.64875
#      -0.00263 |      -0.00644 |     137.46811 |       0.00066 |       0.64429
#      -0.00430 |      -0.00638 |     125.38188 |       0.00187 |       0.63790
# Evaluating losses...
#      -0.00602 |      -0.00634 |     117.20485 |       0.00286 |       0.63407
# -----------------------------------
# | EpLenMean       | 28.2          |
# | EpRewMean       | 28.2          |
# | EpThisIter      | 4             |
# | EpisodesSoFar   | 32            |
# | TimeElapsed     | 1.44          |
# | TimestepsSoFar  | 1082          |
# | ev_tdlam_before | 0.0942        |
# | loss_ent        | 0.63407296    |
# | loss_kl         | 0.0028643105  |
# | loss_pol_entpen | -0.006340729  |
# | loss_pol_surr   | -0.0060165105 |
# | loss_vf_loss    | 117.20485     |
# -----------------------------------
# ********** Iteration 4 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00054 |      -0.00623 |      93.07507 |      4.33e-05 |       0.62320
#      -0.00329 |      -0.00618 |      82.06607 |       0.00039 |       0.61793
#      -0.00740 |      -0.00612 |      71.69442 |       0.00187 |       0.61161
#      -0.01050 |      -0.00604 |      62.50452 |       0.00502 |       0.60419
# Evaluating losses...
#      -0.01112 |      -0.00600 |      57.24994 |       0.00689 |       0.60025
# ----------------------------------
# | EpLenMean       | 32.4         |
# | EpRewMean       | 32.4         |
# | EpThisIter      | 7            |
# | EpisodesSoFar   | 39           |
# | TimeElapsed     | 1.72         |
# | TimestepsSoFar  | 1459         |
# | ev_tdlam_before | -0.000904    |
# | loss_ent        | 0.6002456    |
# | loss_kl         | 0.0068855947 |
# | loss_pol_entpen | -0.006002456 |
# | loss_pol_surr   | -0.011118427 |
# | loss_vf_loss    | 57.249943    |
# ----------------------------------
# ********** Iteration 5 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00176 |      -0.00610 |      99.81672 |      5.40e-05 |       0.61010
#      -0.00631 |      -0.00600 |      88.98767 |       0.00084 |       0.59980
#      -0.01185 |      -0.00587 |      78.65742 |       0.00309 |       0.58696
#      -0.01326 |      -0.00580 |      69.22042 |       0.00537 |       0.57964
# Evaluating losses...
#      -0.01305 |      -0.00578 |      63.97533 |       0.00617 |       0.57819
# -----------------------------------
# | EpLenMean       | 33.8          |
# | EpRewMean       | 33.8          |
# | EpThisIter      | 6             |
# | EpisodesSoFar   | 45            |
# | TimeElapsed     | 1.99          |
# | TimestepsSoFar  | 1731          |
# | ev_tdlam_before | 0.0158        |
# | loss_ent        | 0.5781926     |
# | loss_kl         | 0.0061686477  |
# | loss_pol_entpen | -0.0057819253 |
# | loss_pol_surr   | -0.0130452635 |
# | loss_vf_loss    | 63.975327     |
# -----------------------------------
# ********** Iteration 6 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -7.24e-05 |      -0.00618 |     162.75418 |       0.00033 |       0.61788
#      -0.00598 |      -0.00617 |     133.65681 |       0.00140 |       0.61672
#      -0.00434 |      -0.00612 |     107.56967 |       0.00623 |       0.61224
#      -0.00592 |      -0.00619 |      88.35069 |       0.00466 |       0.61886
# Evaluating losses...
#      -0.00855 |      -0.00626 |      79.51146 |       0.00168 |       0.62607
# -----------------------------------
# | EpLenMean       | 35.6          |
# | EpRewMean       | 35.6          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 46            |
# | TimeElapsed     | 2.33          |
# | TimestepsSoFar  | 2001          |
# | ev_tdlam_before | 0.652         |
# | loss_ent        | 0.62607145    |
# | loss_kl         | 0.0016751646  |
# | loss_pol_entpen | -0.0062607145 |
# | loss_pol_surr   | -0.008550146  |
# | loss_vf_loss    | 79.51146      |
# -----------------------------------
# ********** Iteration 7 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00230 |      -0.00616 |     155.56758 |       0.00010 |       0.61583
#      -0.00580 |      -0.00609 |     135.80441 |       0.00047 |       0.60898
#      -0.01530 |      -0.00591 |     119.21029 |       0.00285 |       0.59081
#      -0.01471 |      -0.00579 |     105.29019 |       0.00577 |       0.57910
# Evaluating losses...
#      -0.01501 |      -0.00577 |      98.40730 |       0.00672 |       0.57749
# -----------------------------------
# | EpLenMean       | 38.5          |
# | EpRewMean       | 38.5          |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 48            |
# | TimeElapsed     | 2.66          |
# | TimestepsSoFar  | 2413          |
# | ev_tdlam_before | 0.185         |
# | loss_ent        | 0.5774854     |
# | loss_kl         | 0.006720956   |
# | loss_pol_entpen | -0.0057748538 |
# | loss_pol_surr   | -0.015013643  |
# | loss_vf_loss    | 98.4073       |
# -----------------------------------
# ********** Iteration 8 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00141 |      -0.00592 |     144.17285 |       0.00019 |       0.59162
#      -0.00868 |      -0.00590 |     124.87266 |       0.00252 |       0.58960
#      -0.01177 |      -0.00592 |     106.86942 |       0.00458 |       0.59244
#      -0.01312 |      -0.00600 |      92.43723 |       0.00344 |       0.59965
# Evaluating losses...
#      -0.01123 |      -0.00603 |      85.50469 |       0.00316 |       0.60350
# ----------------------------------
# | EpLenMean       | 44.2         |
# | EpRewMean       | 44.2         |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 49           |
# | TimeElapsed     | 2.9          |
# | TimestepsSoFar  | 2871         |
# | ev_tdlam_before | 0.405        |
# | loss_ent        | 0.6034977    |
# | loss_kl         | 0.0031579232 |
# | loss_pol_entpen | -0.006034977 |
# | loss_pol_surr   | -0.011228595 |
# | loss_vf_loss    | 85.50469     |
# ----------------------------------
# ********** Iteration 9 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00042 |      -0.00610 |     136.59398 |      6.18e-05 |       0.60969
#      -0.00365 |      -0.00609 |     127.01025 |       0.00065 |       0.60918
#      -0.01116 |      -0.00605 |     118.39636 |       0.00295 |       0.60491
#      -0.00944 |      -0.00601 |     110.50709 |       0.00538 |       0.60118
# Evaluating losses...
#      -0.01006 |      -0.00601 |     106.27438 |       0.00537 |       0.60071
# -----------------------------------
# | EpLenMean       | 46.7          |
# | EpRewMean       | 46.7          |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 51            |
# | TimeElapsed     | 3.16          |
# | TimestepsSoFar  | 3264          |
# | ev_tdlam_before | 0.191         |
# | loss_ent        | 0.60070753    |
# | loss_kl         | 0.005368107   |
# | loss_pol_entpen | -0.0060070753 |
# | loss_pol_surr   | -0.010058674  |
# | loss_vf_loss    | 106.27438     |
# -----------------------------------
# ********** Iteration 10 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00065 |      -0.00612 |     123.50998 |      3.80e-05 |       0.61193
#      -0.00954 |      -0.00604 |     116.98015 |       0.00231 |       0.60441
#      -0.00893 |      -0.00601 |     110.95166 |       0.00529 |       0.60078
#      -0.01130 |      -0.00607 |     105.37654 |       0.00428 |       0.60657
# Evaluating losses...
#      -0.01290 |      -0.00611 |     102.04781 |       0.00351 |       0.61117
# -----------------------------------
# | EpLenMean       | 51.3          |
# | EpRewMean       | 51.3          |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 53            |
# | TimeElapsed     | 3.49          |
# | TimestepsSoFar  | 3697          |
# | ev_tdlam_before | 0.0995        |
# | loss_ent        | 0.61116904    |
# | loss_kl         | 0.0035071159  |
# | loss_pol_entpen | -0.0061116903 |
# | loss_pol_surr   | -0.012900576  |
# | loss_vf_loss    | 102.047806    |
# -----------------------------------
# ********** Iteration 11 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00185 |      -0.00592 |     122.72702 |       0.00012 |       0.59236
#      -0.01037 |      -0.00593 |     117.46774 |       0.00162 |       0.59337
#      -0.01380 |      -0.00591 |     112.33464 |       0.00563 |       0.59054
#      -0.01349 |      -0.00590 |     107.52950 |       0.00845 |       0.58987
# Evaluating losses...
#      -0.01506 |      -0.00592 |     104.76634 |       0.00812 |       0.59174
# ----------------------------------
# | EpLenMean       | 55           |
# | EpRewMean       | 55           |
# | EpThisIter      | 2            |
# | EpisodesSoFar   | 55           |
# | TimeElapsed     | 3.76         |
# | TimestepsSoFar  | 4050         |
# | ev_tdlam_before | 0.00265      |
# | loss_ent        | 0.59174496   |
# | loss_kl         | 0.008123505  |
# | loss_pol_entpen | -0.00591745  |
# | loss_pol_surr   | -0.015055127 |
# | loss_vf_loss    | 104.76634    |
# ----------------------------------
# ********** Iteration 12 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00027 |      -0.00615 |     121.42618 |      2.45e-05 |       0.61506
#      -0.00123 |      -0.00613 |     116.96919 |       0.00023 |       0.61319
#      -0.00157 |      -0.00611 |     112.41101 |       0.00059 |       0.61085
#      -0.00255 |      -0.00607 |     108.14902 |       0.00114 |       0.60733
# Evaluating losses...
#      -0.00280 |      -0.00606 |     105.74603 |       0.00147 |       0.60602
# -----------------------------------
# | EpLenMean       | 56.7          |
# | EpRewMean       | 56.7          |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 57            |
# | TimeElapsed     | 4.03          |
# | TimestepsSoFar  | 4353          |
# | ev_tdlam_before | 0.00245       |
# | loss_ent        | 0.6060168     |
# | loss_kl         | 0.0014697568  |
# | loss_pol_entpen | -0.006060168  |
# | loss_pol_surr   | -0.0027954886 |
# | loss_vf_loss    | 105.746025    |
# -----------------------------------
# ********** Iteration 13 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00107 |      -0.00607 |     131.62878 |       0.00026 |       0.60653
#      -0.01385 |      -0.00597 |     125.97124 |       0.00211 |       0.59684
#      -0.01252 |      -0.00589 |     120.30418 |       0.00525 |       0.58869
#      -0.01126 |      -0.00585 |     114.83090 |       0.00741 |       0.58515
# Evaluating losses...
#      -0.01173 |      -0.00585 |     111.36003 |       0.00731 |       0.58544
# ----------------------------------
# | EpLenMean       | 59.7         |
# | EpRewMean       | 59.7         |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 58           |
# | TimeElapsed     | 4.35         |
# | TimestepsSoFar  | 4706         |
# | ev_tdlam_before | -0.00803     |
# | loss_ent        | 0.5854407    |
# | loss_kl         | 0.007308086  |
# | loss_pol_entpen | -0.005854407 |
# | loss_pol_surr   | -0.011726878 |
# | loss_vf_loss    | 111.36003    |
# ----------------------------------
# ********** Iteration 14 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00405 |      -0.00613 |     129.15378 |       0.00010 |       0.61328
#      -0.01394 |      -0.00604 |     123.46625 |       0.00175 |       0.60374
#      -0.01053 |      -0.00594 |     117.98599 |       0.00502 |       0.59380
#      -0.00993 |      -0.00589 |     112.83998 |       0.00613 |       0.58937
# Evaluating losses...
#      -0.01106 |      -0.00589 |     109.75540 |       0.00538 |       0.58904
# -----------------------------------
# | EpLenMean       | 62            |
# | EpRewMean       | 62            |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 59            |
# | TimeElapsed     | 4.6           |
# | TimestepsSoFar  | 5085          |
# | ev_tdlam_before | -0.00564      |
# | loss_ent        | 0.5890433     |
# | loss_kl         | 0.0053772693  |
# | loss_pol_entpen | -0.0058904327 |
# | loss_pol_surr   | -0.011058154  |
# | loss_vf_loss    | 109.7554      |
# -----------------------------------
# ********** Iteration 15 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00095 |      -0.00574 |     131.33118 |      1.50e-05 |       0.57441
#      -0.00228 |      -0.00572 |     126.68373 |       0.00081 |       0.57222
#      -0.00235 |      -0.00568 |     122.54665 |       0.00430 |       0.56824
#      -0.00355 |      -0.00572 |     118.48255 |       0.00514 |       0.57173
# Evaluating losses...
#      -0.00570 |      -0.00576 |     115.93456 |       0.00373 |       0.57635
# -----------------------------------
# | EpLenMean       | 65.7          |
# | EpRewMean       | 65.7          |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 61            |
# | TimeElapsed     | 4.85          |
# | TimestepsSoFar  | 5524          |
# | ev_tdlam_before | -0.00441      |
# | loss_ent        | 0.57634854    |
# | loss_kl         | 0.0037344275  |
# | loss_pol_entpen | -0.0057634856 |
# | loss_pol_surr   | -0.0057026166 |
# | loss_vf_loss    | 115.934555    |
# -----------------------------------
# ********** Iteration 16 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      6.51e-05 |      -0.00592 |     124.84982 |      6.14e-05 |       0.59187
#      -0.00420 |      -0.00594 |     119.88032 |       0.00045 |       0.59366
#      -0.00961 |      -0.00590 |     114.83531 |       0.00163 |       0.59024
#      -0.01055 |      -0.00587 |     110.01003 |       0.00317 |       0.58696
# Evaluating losses...
#      -0.01004 |      -0.00586 |     107.19924 |       0.00358 |       0.58587
# ----------------------------------
# | EpLenMean       | 68.5         |
# | EpRewMean       | 68.5         |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 62           |
# | TimeElapsed     | 5.11         |
# | TimestepsSoFar  | 5871         |
# | ev_tdlam_before | -0.013       |
# | loss_ent        | 0.5858661    |
# | loss_kl         | 0.0035822173 |
# | loss_pol_entpen | -0.005858661 |
# | loss_pol_surr   | -0.010042673 |
# | loss_vf_loss    | 107.19924    |
# ----------------------------------
# ********** Iteration 17 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00114 |      -0.00588 |     121.79825 |      1.94e-05 |       0.58826
#      -0.00702 |      -0.00582 |     117.36134 |       0.00155 |       0.58189
#      -0.00834 |      -0.00572 |     113.24945 |       0.00758 |       0.57162
#      -0.00602 |      -0.00566 |     109.19844 |       0.01116 |       0.56613
# Evaluating losses...
#      -0.00687 |      -0.00565 |     106.84894 |       0.01042 |       0.56519
# -----------------------------------
# | EpLenMean       | 71.9          |
# | EpRewMean       | 71.9          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 63            |
# | TimeElapsed     | 5.42          |
# | TimestepsSoFar  | 6234          |
# | ev_tdlam_before | -0.00321      |
# | loss_ent        | 0.56518763    |
# | loss_kl         | 0.010424861   |
# | loss_pol_entpen | -0.0056518763 |
# | loss_pol_surr   | -0.0068727173 |
# | loss_vf_loss    | 106.84894     |
# -----------------------------------
# ********** Iteration 18 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00045 |      -0.00555 |     119.84274 |      2.19e-05 |       0.55470
#      -0.00557 |      -0.00548 |     115.70059 |       0.00040 |       0.54752
#      -0.01009 |      -0.00539 |     111.79411 |       0.00178 |       0.53873
#      -0.00996 |      -0.00535 |     108.05117 |       0.00336 |       0.53517
# Evaluating losses...
#      -0.01028 |      -0.00536 |     105.76942 |       0.00404 |       0.53563
# -----------------------------------
# | EpLenMean       | 74.6          |
# | EpRewMean       | 74.6          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 64            |
# | TimeElapsed     | 5.74          |
# | TimestepsSoFar  | 6571          |
# | ev_tdlam_before | 0.00301       |
# | loss_ent        | 0.5356277     |
# | loss_kl         | 0.0040371194  |
# | loss_pol_entpen | -0.0053562773 |
# | loss_pol_surr   | -0.010283094  |
# | loss_vf_loss    | 105.769424    |
# -----------------------------------
# ********** Iteration 19 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -6.52e-05 |      -0.00568 |     125.87646 |      1.09e-05 |       0.56773
#      -0.00071 |      -0.00570 |     120.27193 |      8.07e-05 |       0.56987
#      -0.00256 |      -0.00572 |     114.40929 |       0.00037 |       0.57249
#      -0.00648 |      -0.00574 |     108.60539 |       0.00109 |       0.57442
# Evaluating losses...
#      -0.00783 |      -0.00576 |     104.98461 |       0.00179 |       0.57581
# -----------------------------------
# | EpLenMean       | 78.8          |
# | EpRewMean       | 78.8          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 65            |
# | TimeElapsed     | 6.09          |
# | TimestepsSoFar  | 6918          |
# | ev_tdlam_before | -0.0386       |
# | loss_ent        | 0.57581496    |
# | loss_kl         | 0.0017895062  |
# | loss_pol_entpen | -0.0057581495 |
# | loss_pol_surr   | -0.0078324545 |
# | loss_vf_loss    | 104.98461     |
# -----------------------------------
# ********** Iteration 20 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00048 |      -0.00574 |     121.55161 |      9.41e-05 |       0.57435
#      -0.00133 |      -0.00575 |     115.75732 |       0.00070 |       0.57535
#      -0.00238 |      -0.00575 |     110.12923 |       0.00187 |       0.57537
#      -0.00397 |      -0.00575 |     104.66855 |       0.00326 |       0.57476
# Evaluating losses...
#      -0.00358 |      -0.00574 |     101.42540 |       0.00405 |       0.57426
# -----------------------------------
# | EpLenMean       | 86.7          |
# | EpRewMean       | 86.7          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 66            |
# | TimeElapsed     | 6.4           |
# | TimestepsSoFar  | 7521          |
# | ev_tdlam_before | -0.0143       |
# | loss_ent        | 0.5742566     |
# | loss_kl         | 0.0040530167  |
# | loss_pol_entpen | -0.0057425653 |
# | loss_pol_surr   | -0.003575664  |
# | loss_vf_loss    | 101.4254      |
# -----------------------------------
# ********** Iteration 21 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00022 |      -0.00578 |     115.27505 |      5.35e-06 |       0.57836
#       0.00094 |      -0.00579 |     111.78722 |      4.24e-05 |       0.57899
#       0.00124 |      -0.00580 |     108.34320 |      8.81e-05 |       0.57976
#       0.00145 |      -0.00580 |     105.38937 |       0.00011 |       0.58001
# Evaluating losses...
#      -0.00037 |      -0.00580 |     103.54128 |      9.31e-05 |       0.57991
# -----------------------------------
# | EpLenMean       | 97.4          |
# | EpRewMean       | 97.4          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 67            |
# | TimeElapsed     | 6.7           |
# | TimestepsSoFar  | 8380          |
# | ev_tdlam_before | 0.00139       |
# | loss_ent        | 0.57991153    |
# | loss_kl         | 9.3080715e-05 |
# | loss_pol_entpen | -0.005799115  |
# | loss_pol_surr   | -0.0003665164 |
# | loss_vf_loss    | 103.54128     |
# -----------------------------------
# ********** Iteration 22 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00057 |      -0.00587 |     114.21729 |      3.68e-05 |       0.58706
#      -0.00411 |      -0.00584 |     111.31690 |       0.00156 |       0.58419
#      -0.00135 |      -0.00581 |     108.61984 |       0.00483 |       0.58149
#      -0.00349 |      -0.00585 |     105.96082 |       0.00322 |       0.58539
# Evaluating losses...
#      -0.00514 |      -0.00590 |     104.48714 |       0.00113 |       0.58994
# -----------------------------------
# | EpLenMean       | 98.1          |
# | EpRewMean       | 98.1          |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 68            |
# | TimeElapsed     | 7.02          |
# | TimestepsSoFar  | 8690          |
# | ev_tdlam_before | 0.000382      |
# | loss_ent        | 0.5899372     |
# | loss_kl         | 0.0011253413  |
# | loss_pol_entpen | -0.0058993725 |
# | loss_pol_surr   | -0.005137939  |
# | loss_vf_loss    | 104.48714     |
# -----------------------------------
# ********** Iteration 23 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00271 |      -0.00595 |     112.83751 |       0.00169 |       0.59512
#      -0.00403 |      -0.00584 |     108.72810 |       0.00911 |       0.58447
#      -0.00475 |      -0.00588 |     104.34195 |       0.00712 |       0.58754
#      -0.01050 |      -0.00597 |      99.94534 |       0.00192 |       0.59661
# Evaluating losses...
#      -0.01095 |      -0.00596 |      97.20949 |       0.00198 |       0.59605
# -----------------------------------
# | EpLenMean       | 103           |
# | EpRewMean       | 103           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 69            |
# | TimeElapsed     | 7.32          |
# | TimestepsSoFar  | 9114          |
# | ev_tdlam_before | -0.0049       |
# | loss_ent        | 0.5960517     |
# | loss_kl         | 0.0019837813  |
# | loss_pol_entpen | -0.0059605166 |
# | loss_pol_surr   | -0.010945618  |
# | loss_vf_loss    | 97.20949      |
# -----------------------------------
# ********** Iteration 24 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00023 |      -0.00579 |     135.52628 |      7.38e-06 |       0.57893
#      -0.00216 |      -0.00577 |     132.97249 |       0.00012 |       0.57656
#      -0.00510 |      -0.00574 |     130.62267 |       0.00069 |       0.57397
#      -0.00773 |      -0.00573 |     128.35532 |       0.00187 |       0.57329
# Evaluating losses...
#      -0.00809 |      -0.00574 |     127.07388 |       0.00274 |       0.57364
# -----------------------------------
# | EpLenMean       | 106           |
# | EpRewMean       | 106           |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 71            |
# | TimeElapsed     | 7.64          |
# | TimestepsSoFar  | 9794          |
# | ev_tdlam_before | -0.000412     |
# | loss_ent        | 0.5736395     |
# | loss_kl         | 0.0027438127  |
# | loss_pol_entpen | -0.0057363953 |
# | loss_pol_surr   | -0.008085013  |
# | loss_vf_loss    | 127.07388     |
# -----------------------------------
# ********** Iteration 25 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00085 |      -0.00590 |     112.98201 |      5.84e-05 |       0.59009
#      -0.00569 |      -0.00589 |     110.79249 |       0.00150 |       0.58932
#      -0.00412 |      -0.00585 |     108.61971 |       0.00565 |       0.58508
#      -0.00491 |      -0.00584 |     106.49507 |       0.00505 |       0.58394
# Evaluating losses...
#      -0.00646 |      -0.00585 |     105.15108 |       0.00230 |       0.58489
# -----------------------------------
# | EpLenMean       | 111           |
# | EpRewMean       | 111           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 72            |
# | TimeElapsed     | 7.94          |
# | TimestepsSoFar  | 10271         |
# | ev_tdlam_before | 0.000364      |
# | loss_ent        | 0.58489484    |
# | loss_kl         | 0.002299536   |
# | loss_pol_entpen | -0.005848948  |
# | loss_pol_surr   | -0.0064581893 |
# | loss_vf_loss    | 105.15108     |
# -----------------------------------
# ********** Iteration 26 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00112 |      -0.00581 |     105.90050 |      8.65e-05 |       0.58074
#      -0.00167 |      -0.00581 |     102.59256 |       0.00103 |       0.58058
#      -0.00159 |      -0.00578 |      99.11145 |       0.00312 |       0.57827
#      -0.00136 |      -0.00577 |      95.54000 |       0.00314 |       0.57700
# Evaluating losses...
#      -0.00224 |      -0.00577 |      93.34215 |       0.00221 |       0.57673
# -----------------------------------
# | EpLenMean       | 114           |
# | EpRewMean       | 114           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 73            |
# | TimeElapsed     | 8.22          |
# | TimestepsSoFar  | 10563         |
# | ev_tdlam_before | -0.00269      |
# | loss_ent        | 0.5767305     |
# | loss_kl         | 0.0022144555  |
# | loss_pol_entpen | -0.005767305  |
# | loss_pol_surr   | -0.0022416906 |
# | loss_vf_loss    | 93.34215      |
# -----------------------------------
# ********** Iteration 27 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -5.02e-05 |      -0.00582 |     103.31875 |       0.00016 |       0.58187
#      -0.00129 |      -0.00580 |      99.64204 |       0.00139 |       0.58013
#      -0.00046 |      -0.00578 |      95.99040 |       0.00395 |       0.57793
#      -0.00210 |      -0.00578 |      92.41089 |       0.00286 |       0.57847
# Evaluating losses...
#      -0.00232 |      -0.00579 |      90.22526 |       0.00149 |       0.57925
# -----------------------------------
# | EpLenMean       | 119           |
# | EpRewMean       | 119           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 74            |
# | TimeElapsed     | 8.52          |
# | TimestepsSoFar  | 11111         |
# | ev_tdlam_before | -0.00427      |
# | loss_ent        | 0.5792543     |
# | loss_kl         | 0.0014890525  |
# | loss_pol_entpen | -0.0057925433 |
# | loss_pol_surr   | -0.0023208745 |
# | loss_vf_loss    | 90.22526      |
# -----------------------------------
# ********** Iteration 28 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00019 |      -0.00569 |     117.78609 |      1.66e-05 |       0.56918
#      -0.00126 |      -0.00571 |     115.44058 |      9.54e-05 |       0.57143
#      -0.00309 |      -0.00575 |     113.32596 |       0.00040 |       0.57486
#      -0.00456 |      -0.00579 |     111.22012 |       0.00175 |       0.57922
# Evaluating losses...
#      -0.00345 |      -0.00582 |     110.05807 |       0.00320 |       0.58207
# -----------------------------------
# | EpLenMean       | 126           |
# | EpRewMean       | 126           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 75            |
# | TimeElapsed     | 8.83          |
# | TimestepsSoFar  | 11915         |
# | ev_tdlam_before | -0.00561      |
# | loss_ent        | 0.58206743    |
# | loss_kl         | 0.003197756   |
# | loss_pol_entpen | -0.005820674  |
# | loss_pol_surr   | -0.0034453226 |
# | loss_vf_loss    | 110.058075    |
# -----------------------------------
# ********** Iteration 29 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00024 |      -0.00593 |      99.30570 |      2.26e-05 |       0.59320
#      -0.00033 |      -0.00594 |      96.51013 |       0.00032 |       0.59410
#      -0.00220 |      -0.00594 |      93.57003 |       0.00159 |       0.59355
#      -0.00264 |      -0.00591 |      90.57817 |       0.00328 |       0.59090
# Evaluating losses...
#      -0.00261 |      -0.00591 |      88.75153 |       0.00317 |       0.59060
# -----------------------------------
# | EpLenMean       | 130           |
# | EpRewMean       | 130           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 76            |
# | TimeElapsed     | 9.14          |
# | TimestepsSoFar  | 12396         |
# | ev_tdlam_before | 0.00578       |
# | loss_ent        | 0.59060156    |
# | loss_kl         | 0.0031680197  |
# | loss_pol_entpen | -0.0059060156 |
# | loss_pol_surr   | -0.0026109042 |
# | loss_vf_loss    | 88.75153      |
# -----------------------------------
# ********** Iteration 30 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00039 |      -0.00567 |     108.52265 |      2.43e-05 |       0.56735
#      -0.00367 |      -0.00564 |     106.70058 |       0.00027 |       0.56362
#      -0.00417 |      -0.00559 |     105.01509 |       0.00098 |       0.55895
#      -0.00446 |      -0.00558 |     103.50412 |       0.00146 |       0.55810
# Evaluating losses...
#      -0.00502 |      -0.00559 |     102.58228 |       0.00153 |       0.55948
# -----------------------------------
# | EpLenMean       | 137           |
# | EpRewMean       | 137           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 77            |
# | TimeElapsed     | 9.47          |
# | TimestepsSoFar  | 13133         |
# | ev_tdlam_before | 0.0111        |
# | loss_ent        | 0.5594822     |
# | loss_kl         | 0.0015338976  |
# | loss_pol_entpen | -0.0055948226 |
# | loss_pol_surr   | -0.005023502  |
# | loss_vf_loss    | 102.582275    |
# -----------------------------------
# ********** Iteration 31 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00071 |      -0.00566 |     109.12005 |      8.83e-06 |       0.56641
#      -0.00539 |      -0.00567 |     107.74694 |       0.00080 |       0.56734
#      -0.00475 |      -0.00568 |     106.37557 |       0.00285 |       0.56750
#      -0.00517 |      -0.00570 |     105.09662 |       0.00326 |       0.56991
# Evaluating losses...
#      -0.00693 |      -0.00572 |     104.26151 |       0.00269 |       0.57202
# ----------------------------------
# | EpLenMean       | 139          |
# | EpRewMean       | 139          |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 78           |
# | TimeElapsed     | 9.8          |
# | TimestepsSoFar  | 13467        |
# | ev_tdlam_before | -0.00279     |
# | loss_ent        | 0.572023     |
# | loss_kl         | 0.002692408  |
# | loss_pol_entpen | -0.00572023  |
# | loss_pol_surr   | -0.006934507 |
# | loss_vf_loss    | 104.261505   |
# ----------------------------------
# ********** Iteration 32 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -9.04e-06 |      -0.00587 |      94.74560 |      5.33e-06 |       0.58714
#     -1.65e-06 |      -0.00588 |      92.54474 |      6.89e-05 |       0.58804
#      -0.00023 |      -0.00589 |      90.19086 |       0.00017 |       0.58876
#      -0.00043 |      -0.00589 |      87.75090 |       0.00031 |       0.58915
# Evaluating losses...
#      -0.00042 |      -0.00589 |      86.19908 |       0.00043 |       0.58941
# ------------------------------------
# | EpLenMean       | 141            |
# | EpRewMean       | 141            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 79             |
# | TimeElapsed     | 10.1           |
# | TimestepsSoFar  | 13802          |
# | ev_tdlam_before | -0.00654       |
# | loss_ent        | 0.58941036     |
# | loss_kl         | 0.000427552    |
# | loss_pol_entpen | -0.005894103   |
# | loss_pol_surr   | -0.00041845068 |
# | loss_vf_loss    | 86.19908       |
# ------------------------------------
# ********** Iteration 33 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00015 |      -0.00598 |      92.96871 |      1.58e-06 |       0.59786
#       0.00017 |      -0.00599 |      90.43567 |      1.55e-05 |       0.59893
#       0.00014 |      -0.00599 |      87.90512 |      2.51e-05 |       0.59938
#      7.71e-05 |      -0.00600 |      85.43365 |      2.11e-05 |       0.59960
# Evaluating losses...
#      -0.00017 |      -0.00600 |      83.88786 |      3.05e-05 |       0.59983
# ------------------------------------
# | EpLenMean       | 147            |
# | EpRewMean       | 147            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 80             |
# | TimeElapsed     | 10.5           |
# | TimestepsSoFar  | 14393          |
# | ev_tdlam_before | -0.00191       |
# | loss_ent        | 0.5998257      |
# | loss_kl         | 3.054506e-05   |
# | loss_pol_entpen | -0.0059982566  |
# | loss_pol_surr   | -0.00016728044 |
# | loss_vf_loss    | 83.887856      |
# ------------------------------------
# ********** Iteration 34 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00047 |      -0.00578 |     113.29842 |      2.19e-06 |       0.57802
#      -0.00360 |      -0.00576 |     111.81540 |       0.00010 |       0.57629
#      -0.00492 |      -0.00574 |     110.45334 |       0.00049 |       0.57352
#      -0.00433 |      -0.00573 |     109.16743 |       0.00078 |       0.57320
# Evaluating losses...
#      -0.00434 |      -0.00574 |     108.42202 |       0.00086 |       0.57388
# -----------------------------------
# | EpLenMean       | 153           |
# | EpRewMean       | 153           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 81            |
# | TimeElapsed     | 10.8          |
# | TimestepsSoFar  | 15240         |
# | ev_tdlam_before | -0.00561      |
# | loss_ent        | 0.57388216    |
# | loss_kl         | 0.0008609566  |
# | loss_pol_entpen | -0.0057388213 |
# | loss_pol_surr   | -0.004341703  |
# | loss_vf_loss    | 108.42202     |
# -----------------------------------
# ********** Iteration 35 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00040 |      -0.00587 |      90.59119 |      4.05e-06 |       0.58746
#      7.90e-05 |      -0.00588 |      88.72862 |      1.52e-05 |       0.58821
#      9.73e-05 |      -0.00589 |      86.75021 |      3.05e-05 |       0.58917
#      7.95e-05 |      -0.00590 |      84.71577 |      5.40e-05 |       0.59021
# Evaluating losses...
#     -6.07e-05 |      -0.00591 |      83.43327 |      7.09e-05 |       0.59082
# ------------------------------------
# | EpLenMean       | 157            |
# | EpRewMean       | 157            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 82             |
# | TimeElapsed     | 11.1           |
# | TimestepsSoFar  | 15712          |
# | ev_tdlam_before | -0.028         |
# | loss_ent        | 0.59081566     |
# | loss_kl         | 7.0898655e-05  |
# | loss_pol_entpen | -0.005908157   |
# | loss_pol_surr   | -6.0696155e-05 |
# | loss_vf_loss    | 83.43327       |
# ------------------------------------
# ********** Iteration 36 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00046 |      -0.00601 |      88.96644 |      8.31e-06 |       0.60143
#     -4.53e-05 |      -0.00602 |      86.96269 |      1.23e-05 |       0.60241
#       0.00030 |      -0.00603 |      84.94463 |      4.28e-05 |       0.60270
#      -0.00087 |      -0.00603 |      82.96451 |       0.00014 |       0.60328
# Evaluating losses...
#      -0.00117 |      -0.00604 |      81.73358 |       0.00019 |       0.60389
# -----------------------------------
# | EpLenMean       | 163           |
# | EpRewMean       | 163           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 83            |
# | TimeElapsed     | 11.4          |
# | TimestepsSoFar  | 16440         |
# | ev_tdlam_before | -0.0107       |
# | loss_ent        | 0.6038929     |
# | loss_kl         | 0.00019330636 |
# | loss_pol_entpen | -0.00603893   |
# | loss_pol_surr   | -0.0011733361 |
# | loss_vf_loss    | 81.73358      |
# -----------------------------------
# ********** Iteration 37 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00030 |      -0.00564 |     107.87946 |      1.90e-05 |       0.56359
#      -0.00262 |      -0.00562 |     106.85178 |       0.00012 |       0.56217
#      -0.00317 |      -0.00559 |     105.87791 |       0.00062 |       0.55868
#      -0.00177 |      -0.00557 |     105.06264 |       0.00098 |       0.55729
# Evaluating losses...
#      -0.00234 |      -0.00559 |     104.51559 |       0.00083 |       0.55879
# -----------------------------------
# | EpLenMean       | 172           |
# | EpRewMean       | 172           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 84            |
# | TimeElapsed     | 11.7          |
# | TimestepsSoFar  | 17424         |
# | ev_tdlam_before | -0.000955     |
# | loss_ent        | 0.55878973    |
# | loss_kl         | 0.00083318294 |
# | loss_pol_entpen | -0.0055878973 |
# | loss_pol_surr   | -0.0023393482 |
# | loss_vf_loss    | 104.51559     |
# -----------------------------------
# ********** Iteration 38 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00011 |      -0.00591 |      88.08383 |      8.29e-06 |       0.59088
#      -0.00064 |      -0.00591 |      85.86667 |       0.00019 |       0.59128
#      -0.00231 |      -0.00591 |      83.24191 |       0.00080 |       0.59121
#      -0.00242 |      -0.00591 |      80.57668 |       0.00094 |       0.59125
# Evaluating losses...
#      -0.00245 |      -0.00591 |      78.96979 |       0.00065 |       0.59135
# -----------------------------------
# | EpLenMean       | 174           |
# | EpRewMean       | 174           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 85            |
# | TimeElapsed     | 12            |
# | TimestepsSoFar  | 17761         |
# | ev_tdlam_before | 0.0996        |
# | loss_ent        | 0.59135264    |
# | loss_kl         | 0.0006544913  |
# | loss_pol_entpen | -0.0059135263 |
# | loss_pol_surr   | -0.002450619  |
# | loss_vf_loss    | 78.96979      |
# -----------------------------------
# ********** Iteration 39 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      8.86e-05 |      -0.00603 |     109.45843 |      5.09e-06 |       0.60340
#      2.06e-05 |      -0.00604 |     108.55934 |      1.01e-05 |       0.60390
#      -0.00027 |      -0.00606 |     107.68075 |      2.57e-05 |       0.60577
#      -0.00090 |      -0.00608 |     106.87809 |       0.00019 |       0.60843
# Evaluating losses...
#      -0.00168 |      -0.00610 |     106.41002 |       0.00036 |       0.61026
# -----------------------------------
# | EpLenMean       | 179           |
# | EpRewMean       | 179           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 86            |
# | TimeElapsed     | 12.3          |
# | TimestepsSoFar  | 18354         |
# | ev_tdlam_before | 0.0717        |
# | loss_ent        | 0.610263      |
# | loss_kl         | 0.00036206248 |
# | loss_pol_entpen | -0.0061026304 |
# | loss_pol_surr   | -0.0016820431 |
# | loss_vf_loss    | 106.41002     |
# -----------------------------------
# ********** Iteration 40 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -4.31e-05 |      -0.00600 |      85.33493 |      2.34e-06 |       0.59989
#       0.00017 |      -0.00601 |      84.15758 |      1.17e-05 |       0.60104
#      1.96e-05 |      -0.00602 |      82.90628 |      3.03e-05 |       0.60212
#     -2.15e-05 |      -0.00603 |      81.60217 |      4.71e-05 |       0.60282
# Evaluating losses...
#     -3.33e-05 |      -0.00603 |      80.77316 |      5.56e-05 |       0.60313
# ------------------------------------
# | EpLenMean       | 180            |
# | EpRewMean       | 180            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 87             |
# | TimeElapsed     | 12.6           |
# | TimestepsSoFar  | 18623          |
# | ev_tdlam_before | -0.00974       |
# | loss_ent        | 0.60312617     |
# | loss_kl         | 5.5551624e-05  |
# | loss_pol_entpen | -0.0060312613  |
# | loss_pol_surr   | -3.3296645e-05 |
# | loss_vf_loss    | 80.77316       |
# ------------------------------------
# ********** Iteration 41 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      7.82e-06 |      -0.00623 |     109.21733 |      2.66e-07 |       0.62251
#      -0.00107 |      -0.00622 |     108.48890 |      6.93e-05 |       0.62214
#      -0.00189 |      -0.00621 |     107.84248 |       0.00041 |       0.62138
#      -0.00188 |      -0.00622 |     107.19191 |       0.00033 |       0.62209
# Evaluating losses...
#      -0.00168 |      -0.00623 |     106.83391 |       0.00019 |       0.62276
# -----------------------------------
# | EpLenMean       | 183           |
# | EpRewMean       | 183           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 88            |
# | TimeElapsed     | 12.9          |
# | TimestepsSoFar  | 19148         |
# | ev_tdlam_before | -0.000683     |
# | loss_ent        | 0.6227568     |
# | loss_kl         | 0.00018695515 |
# | loss_pol_entpen | -0.006227568  |
# | loss_pol_surr   | -0.0016792342 |
# | loss_vf_loss    | 106.83391     |
# -----------------------------------
# ********** Iteration 42 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00028 |      -0.00594 |      83.84982 |      5.74e-06 |       0.59423
#       0.00014 |      -0.00594 |      82.85568 |      3.31e-05 |       0.59427
#       0.00011 |      -0.00594 |      81.78553 |      4.03e-05 |       0.59403
#       0.00018 |      -0.00594 |      80.65816 |      6.42e-05 |       0.59364
# Evaluating losses...
#      -0.00021 |      -0.00593 |      79.95000 |      9.02e-05 |       0.59331
# ------------------------------------
# | EpLenMean       | 185            |
# | EpRewMean       | 185            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 89             |
# | TimeElapsed     | 13.2           |
# | TimestepsSoFar  | 19441          |
# | ev_tdlam_before | -0.0104        |
# | loss_ent        | 0.5933051      |
# | loss_kl         | 9.01907e-05    |
# | loss_pol_entpen | -0.005933051   |
# | loss_pol_surr   | -0.00021340046 |
# | loss_vf_loss    | 79.950005      |
# ------------------------------------
# ********** Iteration 43 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00039 |      -0.00570 |     137.84927 |      1.18e-05 |       0.56958
#      -0.00221 |      -0.00569 |     137.64320 |       0.00015 |       0.56857
#      -0.00251 |      -0.00569 |     137.46201 |       0.00028 |       0.56950
#      -0.00280 |      -0.00572 |     137.29784 |       0.00023 |       0.57231
# Evaluating losses...
#      -0.00291 |      -0.00574 |     137.22374 |       0.00023 |       0.57420
# -----------------------------------
# | EpLenMean       | 186           |
# | EpRewMean       | 186           |
# | EpThisIter      | 2             |
# | EpisodesSoFar   | 91            |
# | TimeElapsed     | 13.5          |
# | TimestepsSoFar  | 19990         |
# | ev_tdlam_before | -0.00199      |
# | loss_ent        | 0.5742047     |
# | loss_kl         | 0.00022855254 |
# | loss_pol_entpen | -0.0057420465 |
# | loss_pol_surr   | -0.0029103328 |
# | loss_vf_loss    | 137.22374     |
# -----------------------------------
# ********** Iteration 44 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -1.69e-05 |      -0.00582 |      82.88721 |      5.27e-06 |       0.58222
#      -0.00231 |      -0.00583 |      82.24237 |      7.88e-05 |       0.58307
#      -0.00155 |      -0.00584 |      81.45667 |       0.00026 |       0.58353
#      -0.00212 |      -0.00585 |      80.57504 |       0.00026 |       0.58523
# Evaluating losses...
#      -0.00305 |      -0.00587 |      80.00169 |       0.00020 |       0.58681
# -----------------------------------
# | EpLenMean       | 187           |
# | EpRewMean       | 187           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 92            |
# | TimeElapsed     | 14            |
# | TimestepsSoFar  | 20291         |
# | ev_tdlam_before | -0.0158       |
# | loss_ent        | 0.5868137     |
# | loss_kl         | 0.00019814537 |
# | loss_pol_entpen | -0.0058681364 |
# | loss_pol_surr   | -0.0030531883 |
# | loss_vf_loss    | 80.001686     |
# -----------------------------------
# ********** Iteration 45 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00033 |      -0.00586 |     109.43629 |      2.68e-05 |       0.58553
#      -0.00267 |      -0.00587 |     108.96160 |       0.00021 |       0.58653
#      -0.00263 |      -0.00588 |     108.48463 |       0.00031 |       0.58787
#      -0.00221 |      -0.00589 |     108.07607 |       0.00027 |       0.58924
# Evaluating losses...
#      -0.00231 |      -0.00590 |     107.79645 |       0.00027 |       0.58955
# ----------------------------------
# | EpLenMean       | 189          |
# | EpRewMean       | 189          |
# | EpThisIter      | 1            |
# | EpisodesSoFar   | 93           |
# | TimeElapsed     | 14.5         |
# | TimestepsSoFar  | 20848        |
# | ev_tdlam_before | -0.00258     |
# | loss_ent        | 0.58955264   |
# | loss_kl         | 0.0002706157 |
# | loss_pol_entpen | -0.005895526 |
# | loss_pol_surr   | -0.002312677 |
# | loss_vf_loss    | 107.79645    |
# ----------------------------------
# ********** Iteration 46 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00017 |      -0.00606 |      82.14175 |      2.30e-06 |       0.60567
#     -5.07e-05 |      -0.00606 |      81.44073 |      4.60e-06 |       0.60589
#      -0.00020 |      -0.00606 |      80.66729 |      6.46e-06 |       0.60634
#      -0.00031 |      -0.00607 |      79.85599 |      1.26e-05 |       0.60682
# Evaluating losses...
#      -0.00039 |      -0.00607 |      79.33688 |      1.91e-05 |       0.60717
# ------------------------------------
# | EpLenMean       | 192            |
# | EpRewMean       | 192            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 94             |
# | TimeElapsed     | 15             |
# | TimestepsSoFar  | 21297          |
# | ev_tdlam_before | -0.0192        |
# | loss_ent        | 0.60716766     |
# | loss_kl         | 1.9050733e-05  |
# | loss_pol_entpen | -0.0060716765  |
# | loss_pol_surr   | -0.00039462466 |
# | loss_vf_loss    | 79.33688       |
# ------------------------------------
# ********** Iteration 47 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      6.32e-05 |      -0.00588 |     106.99858 |      4.70e-07 |       0.58799
#     -4.34e-05 |      -0.00588 |     106.58271 |      2.78e-06 |       0.58831
#      -0.00021 |      -0.00589 |     106.16420 |      6.69e-06 |       0.58874
#      -0.00032 |      -0.00589 |     105.76458 |      1.68e-05 |       0.58906
# Evaluating losses...
#      -0.00061 |      -0.00589 |     105.52554 |      3.01e-05 |       0.58903
# -----------------------------------
# | EpLenMean       | 196           |
# | EpRewMean       | 196           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 95            |
# | TimeElapsed     | 15.4          |
# | TimestepsSoFar  | 22002         |
# | ev_tdlam_before | 0.0299        |
# | loss_ent        | 0.5890326     |
# | loss_kl         | 3.0140072e-05 |
# | loss_pol_entpen | -0.0058903256 |
# | loss_pol_surr   | -0.000611186  |
# | loss_vf_loss    | 105.52554     |
# -----------------------------------
# ********** Iteration 48 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00019 |      -0.00605 |     108.40274 |      1.11e-06 |       0.60511
#      -0.00042 |      -0.00604 |     108.15930 |      3.16e-05 |       0.60410
#      -0.00062 |      -0.00603 |     107.90622 |      7.89e-05 |       0.60334
#      -0.00054 |      -0.00603 |     107.66866 |      8.51e-05 |       0.60333
# Evaluating losses...
#      -0.00066 |      -0.00604 |     107.51065 |      7.24e-05 |       0.60361
# -----------------------------------
# | EpLenMean       | 197           |
# | EpRewMean       | 197           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 96            |
# | TimeElapsed     | 15.8          |
# | TimestepsSoFar  | 22420         |
# | ev_tdlam_before | -0.00143      |
# | loss_ent        | 0.60360837    |
# | loss_kl         | 7.2414376e-05 |
# | loss_pol_entpen | -0.006036083  |
# | loss_pol_surr   | -0.0006646775 |
# | loss_vf_loss    | 107.51065     |
# -----------------------------------
# ********** Iteration 49 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00013 |      -0.00614 |      80.74457 |      7.06e-07 |       0.61406
#      -0.00062 |      -0.00614 |      80.33403 |      1.33e-05 |       0.61429
#      -0.00111 |      -0.00614 |      79.87881 |      6.23e-05 |       0.61443
#      -0.00087 |      -0.00615 |      79.39497 |      9.08e-05 |       0.61454
# Evaluating losses...
#      -0.00095 |      -0.00615 |      79.08496 |      8.47e-05 |       0.61462
# ------------------------------------
# | EpLenMean       | 199            |
# | EpRewMean       | 199            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 97             |
# | TimeElapsed     | 16             |
# | TimestepsSoFar  | 22791          |
# | ev_tdlam_before | -0.00664       |
# | loss_ent        | 0.61461836     |
# | loss_kl         | 8.471997e-05   |
# | loss_pol_entpen | -0.0061461832  |
# | loss_pol_surr   | -0.00094606355 |
# | loss_vf_loss    | 79.08496       |
# ------------------------------------
# ********** Iteration 50 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#       0.00020 |      -0.00608 |     110.03664 |      3.53e-06 |       0.60816
#      -0.00098 |      -0.00608 |     109.81093 |      1.94e-05 |       0.60801
#      -0.00100 |      -0.00608 |     109.57426 |      2.65e-05 |       0.60850
#      -0.00097 |      -0.00610 |     109.37343 |      1.95e-05 |       0.60963
# Evaluating losses...
#      -0.00118 |      -0.00610 |     109.25554 |      2.51e-05 |       0.61010
# -----------------------------------
# | EpLenMean       | 201           |
# | EpRewMean       | 201           |
# | EpThisIter      | 1             |
# | EpisodesSoFar   | 98            |
# | TimeElapsed     | 16.3          |
# | TimestepsSoFar  | 23418         |
# | ev_tdlam_before | -0.00326      |
# | loss_ent        | 0.6101047     |
# | loss_kl         | 2.5103192e-05 |
# | loss_pol_entpen | -0.0061010467 |
# | loss_pol_surr   | -0.0011777449 |
# | loss_vf_loss    | 109.25554     |
# -----------------------------------
# ********** Iteration 51 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      7.13e-05 |      -0.00613 |      80.09454 |      1.76e-07 |       0.61313
#      5.07e-05 |      -0.00613 |      79.82900 |      9.38e-07 |       0.61341
#      1.14e-06 |      -0.00614 |      79.53996 |      2.06e-06 |       0.61354
#     -6.40e-05 |      -0.00614 |      79.23544 |      4.20e-06 |       0.61355
# Evaluating losses...
#      -0.00012 |      -0.00613 |      79.03925 |      6.41e-06 |       0.61349
# ------------------------------------
# | EpLenMean       | 204            |
# | EpRewMean       | 204            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 99             |
# | TimeElapsed     | 16.5           |
# | TimestepsSoFar  | 23870          |
# | ev_tdlam_before | 0.0819         |
# | loss_ent        | 0.613486       |
# | loss_kl         | 6.4127e-06     |
# | loss_pol_entpen | -0.0061348598  |
# | loss_pol_surr   | -0.00011988729 |
# | loss_vf_loss    | 79.039246      |
# ------------------------------------
# ********** Iteration 52 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#      -0.00020 |      -0.00620 |     105.09312 |      7.15e-07 |       0.61982
#      -0.00028 |      -0.00620 |     104.95219 |      1.38e-05 |       0.61961
#      -0.00016 |      -0.00620 |     104.80921 |      2.24e-05 |       0.61956
#      -0.00039 |      -0.00620 |     104.66331 |      7.81e-06 |       0.61963
# Evaluating losses...
#      -0.00032 |      -0.00620 |     104.56607 |      1.31e-06 |       0.61977
# ------------------------------------
# | EpLenMean       | 208            |
# | EpRewMean       | 208            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 100            |
# | TimeElapsed     | 16.7           |
# | TimestepsSoFar  | 24578          |
# | ev_tdlam_before | 0.0665         |
# | loss_ent        | 0.6197721      |
# | loss_kl         | 1.3090489e-06  |
# | loss_pol_entpen | -0.0061977208  |
# | loss_pol_surr   | -0.00032200664 |
# | loss_vf_loss    | 104.56607      |
# ------------------------------------
# ********** Iteration 53 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -5.15e-05 |      -0.00604 |     109.52522 |      1.38e-07 |       0.60404
#      -0.00021 |      -0.00604 |     109.48826 |      1.48e-06 |       0.60394
#      -0.00015 |      -0.00604 |     109.45110 |      3.16e-06 |       0.60394
#      -0.00015 |      -0.00604 |     109.41594 |      3.40e-06 |       0.60398
# Evaluating losses...
#      -0.00018 |      -0.00604 |     109.39324 |      2.82e-06 |       0.60402
# ------------------------------------
# | EpLenMean       | 211            |
# | EpRewMean       | 211            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 101            |
# | TimeElapsed     | 16.9           |
# | TimestepsSoFar  | 24926          |
# | ev_tdlam_before | 0.0147         |
# | loss_ent        | 0.6040199      |
# | loss_kl         | 2.8230088e-06  |
# | loss_pol_entpen | -0.0060401987  |
# | loss_pol_surr   | -0.00018123537 |
# | loss_vf_loss    | 109.39324      |
# ------------------------------------
# ********** Iteration 54 ************
# Optimizing...
#      pol_surr |    pol_entpen |       vf_loss |            kl |           ent
#     -6.41e-07 |      -0.00582 |     112.67785 |     -9.68e-10 |       0.58173
#     -1.41e-05 |      -0.00582 |     112.67157 |      5.52e-09 |       0.58171
#     -2.14e-05 |      -0.00582 |     112.66481 |      3.08e-08 |       0.58169
#     -1.71e-05 |      -0.00582 |     112.65834 |      6.27e-08 |       0.58168
# Evaluating losses...
#     -1.77e-05 |      -0.00582 |     112.65415 |      6.82e-08 |       0.58168
# ------------------------------------
# | EpLenMean       | 213            |
# | EpRewMean       | 213            |
# | EpThisIter      | 1              |
# | EpisodesSoFar   | 102            |
# | TimeElapsed     | 17.1           |
# | TimestepsSoFar  | 25210          |
# | ev_tdlam_before | -0.00243       |
# | loss_ent        | 0.5816776      |
# | loss_kl         | 6.8179006e-08  |
# | loss_pol_entpen | -0.0058167754  |
# | loss_pol_surr   | -1.7699786e-05 |
# | loss_vf_loss    | 112.65415      |
# ------------------------------------

# %%
del model # remove to demonstrate saving and loading

# %%
model = PPO1.load("ppo1_cartpole")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.

# %%
obs = env.reset()

# %%
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-9232eba46886> in <module>()
#       1 while True:
# ----> 2     action, _states = model.predict(obs)
#       3     obs, rewards, dones, info = env.step(action)
#       4     env.render()
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/stable_baselines/ppo1/pposgd_simple.py in predict(self, observation, state, mask)
#     245         observation = np.array(observation).reshape((-1,) + self.observation_space.shape)
#     246
# --> 247         actions, _, states, _ = self.step(observation, state, mask)
#     248         return actions, states
#     249
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/stable_baselines/common/policies.py in step(self, obs, state, mask)
#     211
#     212     def step(self, obs, state=None, mask=None):
# --> 213         action, value, neglogp = self.sess.run([self.action, self._value, self.neglogp], {self.obs_ph: obs})
#     214         return action, value, self.initial_state, neglogp
#     215
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     # TODO(yuanbyu, keveman): Revisit whether we should just treat feeding
#    1127     # of a handle from a different device as an error.
# -> 1128     _ = self._update_with_movers(feed_dict_tensor, feed_map)
#    1129     final_fetches = fetch_handler.fetches()
#    1130     final_targets = fetch_handler.targets()
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/client/session.py in _update_with_movers(self, feed_dict, feed_map)
#    1382     handle_movers = []
#    1383     for feed_name, val in feed_map.items():
# -> 1384       mover = session_ops._get_handle_mover(self.graph, *val)
#    1385       if mover:
#    1386         handle_movers.append((feed_name, val[1], mover))
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/session_ops.py in _get_handle_mover(graph, feeder, handle)
#     276 def _get_handle_mover(graph, feeder, handle):
#     277   """Return a move subgraph for this pair of feeder and handle."""
# --> 278   dtype = _get_handle_feeder(graph, feeder)
#     279   if dtype is None:
#     280     return None
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/session_ops.py in _get_handle_feeder(graph, feeder)
#     255
#     256 def _get_handle_feeder(graph, feeder):
# --> 257   return graph._handle_feeders.get(feeder.op.name)
#     258
#     259
#
# /usr/local/miniconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in op(self)
#     313     self._id = uid()
#     314
# --> 315   @property
#     316   def op(self):
#     317     """The `Operation` that produces this tensor as an output."""
#
# KeyboardInterrupt:
